# %%
# =========================
# ======== FLUJO 1 ========
# =========================

"F1_START_A": {
    "type": "task",
    "titulo": "Solicitar eliminación / ajuste de OC",
    "rol": "Usuario",
    "descripcion": "Solicitar formalmente el ajuste o eliminación de la Orden de Compra.",
    "acciones": [
        "Identificar Orden de Compra a ajustar o eliminar",
        "Justificar motivo del ajuste o eliminación",
        "Adjuntar respaldo (correo u otro medio formal)"
    ],
    "next": "F1_REVISAR_HES"
},

"F1_REVISAR_HES": {
    "type": "task",
    "titulo": "Revisar HES creadas",
    "rol": "Ingeniero Logística y Abastecimiento",
    "descripcion": "Revisar si existen HES asociadas a la Orden de Compra.",
    "acciones": [
        "Consultar HES asociadas a la OC en SAP",
        "Validar existencia de HES",
        "Verificar estado de las HES"
    ],
    "next": "F1_DEC_HES_EXISTEN"
},

"F1_DEC_HES_EXISTEN": {
    "type": "decision",
    "titulo": "¿Existen HES creadas?",
    "rol": "Ingeniero Logística y Abastecimiento",
    "descripcion": "Determinar si la OC posee HES asociadas.",
    "opciones": {
        "SI": "F1_DEC_HES_FACTURA",
        "NO": "F1_NO_HES_BORRAR_POS"
    }
},

# =========================
# ===== RAMA NO HES =======
# =========================

"F1_NO_HES_BORRAR_POS": {
    "type": "task",
    "titulo": "Marcar todas las posiciones y borrar",
    "rol": "Abastecimiento",
    "descripcion": "Eliminar todas las posiciones de la Orden de Compra.",
    "acciones": [
        "Seleccionar todas las posiciones de la OC",
        "Marcar posiciones para eliminación",
        "Guardar cambios"
    ],
    "next": "F1_NO_HES_INFO_USUARIO"
},

"F1_NO_HES_INFO_USUARIO": {
    "type": "task",
    "titulo": "Informar a usuario eliminación posiciones",
    "rol": "Abastecimiento",
    "descripcion": "Informar al usuario que las posiciones fueron eliminadas.",
    "acciones": [
        "Notificar al usuario solicitante",
        "Confirmar eliminación de posiciones"
    ],
    "next": "F1_DEC_SOLPED_LIB"
},

"F1_DEC_SOLPED_LIB": {
    "type": "decision",
    "titulo": "¿SOLPED con estrategia de liberación?",
    "rol": "Abastecimiento",
    "descripcion": "Validar si la SOLPED requiere anulación de liberación.",
    "opciones": {
        "SI": "F1_SOLPED_ANULAR_SOLICITAR",
        "NO": "F1_SOLPED_BORRAR"
    }
},

"F1_SOLPED_ANULAR_SOLICITAR": {
    "type": "task",
    "titulo": "Solicitar anulación de liberación de SOLPED",
    "rol": "Abastecimiento",
    "descripcion": "Solicitar anulación de liberación de la SOLPED.",
    "acciones": [
        "Solicitar anulación de liberación en sistema",
        "Verificar solicitud"
    ],
    "next": "F1_SOLPED_ANULAR_EJECUTAR"
},

"F1_SOLPED_ANULAR_EJECUTAR": {
    "type": "task",
    "titulo": "Realizar anulación de liberación",
    "rol": "Abastecimiento",
    "descripcion": "Ejecutar anulación de liberación de la SOLPED.",
    "acciones": [
        "Ejecutar anulación en SAP",
        "Confirmar estado de liberación"
    ],
    "next": "F1_SOLPED_BORRAR"
},

"F1_SOLPED_BORRAR": {
    "type": "task",
    "titulo": "Borrar SOLPED",
    "rol": "Abastecimiento",
    "descripcion": "Eliminar la SOLPED del sistema.",
    "acciones": [
        "Eliminar SOLPED en SAP",
        "Guardar cambios"
    ],
    "next": "F1_END_NO_HES"
},

"F1_END_NO_HES": {
    "type": "end",
    "titulo": "Proceso finalizado (sin HES)",
    "show_tables": True
},

# =========================
# ===== RAMA SI HES =======
# =========================

"F1_DEC_HES_FACTURA": {
    "type": "decision",
    "titulo": "¿HES con factura asociada?",
    "rol": "Ingeniero Logística y Abastecimiento",
    "descripcion": "Validar si las HES tienen factura asociada.",
    "inputs": [
        {"label": "Ingresa número de HES", "key": "numero_hes", "required": True}
    ],
    "opciones": {
        "SI": "F1_HES_FACTURA_SI",
        "NO": "F1_HES_FACTURA_NO"
    }
},

# ----- HES con factura -----

"F1_HES_FACTURA_SI": {
    "type": "task",
    "titulo": "Ajustar valores a suma de HES",
    "rol": "Abastecimiento",
    "descripcion": "Ajustar valores de la OC según las HES existentes.",
    "acciones": [
        "Calcular suma de HES",
        "Ajustar valores de la OC",
        "Guardar cambios"
    ],
    "next": "F1_ELIMINAR_POS"
},

"F1_ELIMINAR_POS": {
    "type": "task",
    "titulo": "Eliminar posiciones restantes",
    "rol": "Abastecimiento",
    "descripcion": "Eliminar posiciones que no corresponden.",
    "acciones": [
        "Identificar posiciones restantes",
        "Eliminar posiciones",
        "Guardar cambios"
    ],
    "next": "F1_END_HES_FACTURA"
},

"F1_END_HES_FACTURA": {
    "type": "end",
    "titulo": "Proceso finalizado (HES con factura)",
    "show_tables": True
},

# ----- HES sin factura -----

"F1_HES_FACTURA_NO": {
    "type": "task",
    "titulo": "Comunicar necesidad de anulación de HES",
    "rol": "Abastecimiento",
    "descripcion": "Informar al usuario la necesidad de anulación de HES.",
    "acciones": [
        "Notificar usuario",
        "Confirmar recepción de información"
    ],
    "next": "F1_SOLICITAR_ANULACION_HES"
},

"F1_SOLICITAR_ANULACION_HES": {
    "type": "task",
    "titulo": "Solicitar anulación de liberación de HES",
    "rol": "Abastecimiento",
    "descripcion": "Solicitar anulación de liberación de HES.",
    "acciones": [
        "Solicitar anulación en sistema",
        "Verificar solicitud"
    ],
    "next": "F1_REALIZAR_ANULACION_HES"
},

"F1_REALIZAR_ANULACION_HES": {
    "type": "task",
    "titulo": "Realizar anulación de liberación",
    "rol": "Abastecimiento",
    "descripcion": "Ejecutar anulación de liberación de HES.",
    "acciones": [
        "Ejecutar anulación",
        "Confirmar estado"
    ],
    "next": "F1_BORRAR_HES"
},

"F1_BORRAR_HES": {
    "type": "task",
    "titulo": "Borrar HES",
    "rol": "Abastecimiento",
    "descripcion": "Eliminar HES del sistema.",
    "acciones": [
        "Eliminar HES en SAP",
        "Guardar cambios"
    ],
    "next": "F1_DEC_AJUSTE_TOTAL"
},

"F1_DEC_AJUSTE_TOTAL": {
    "type": "decision",
    "titulo": "¿El ajuste es total?",
    "rol": "Abastecimiento",
    "descripcion": "Determinar si el ajuste es total o parcial.",
    "opciones": {
        "SI": "F1_BORRAR_PEDIDO",
        "NO": "F1_AJUSTAR_PEDIDO"
    }
},

# ----- ajuste parcial -----

"F1_AJUSTAR_PEDIDO": {
    "type": "task",
    "titulo": "Ajustar pedido",
    "rol": "Abastecimiento",
    "descripcion": "Modificar el pedido según corresponda.",
    "acciones": [
        "Modificar pedido en SAP",
        "Guardar cambios"
    ],
    "next": "F1_AJUSTAR_SOLPED"
},

"F1_AJUSTAR_SOLPED": {
    "type": "task",
    "titulo": "Ajustar SOLPED",
    "rol": "Abastecimiento",
    "descripcion": "Ajustar la SOLPED asociada.",
    "acciones": [
        "Modificar SOLPED",
        "Guardar cambios"
    ],
    "next": "F1_END_AJUSTE_PARCIAL"
},

"F1_END_AJUSTE_PARCIAL": {
    "type": "end",
    "titulo": "Proceso finalizado (ajuste parcial)",
    "show_tables": True
},

# ----- ajuste total -----

"F1_BORRAR_PEDIDO": {
    "type": "task",
    "titulo": "Borrar pedido",
    "rol": "Abastecimiento",
    "descripcion": "Eliminar pedido completamente.",
    "acciones": [
        "Eliminar pedido en SAP",
        "Guardar cambios"
    ],
    "next": "F1_SOLPED_LIBERAR"
},

"F1_SOLPED_LIBERAR": {
    "type": "task",
    "titulo": "Solicitar liberación de SOLPED",
    "rol": "Abastecimiento",
    "descripcion": "Solicitar anulación de liberación de SOLPED.",
    "acciones": [
        "Solicitar liberación",
        "Verificar solicitud"
    ],
    "next": "F1_SOLPED_ANULAR_FINAL"
},

"F1_SOLPED_ANULAR_FINAL": {
    "type": "task",
    "titulo": "Realizar anulación de liberación",
    "rol": "Abastecimiento",
    "descripcion": "Ejecutar anulación de liberación.",
    "acciones": [
        "Ejecutar anulación",
        "Confirmar estado"
    ],
    "next": "F1_SOLPED_BORRAR_FINAL"
},

"F1_SOLPED_BORRAR_FINAL": {
    "type": "task",
    "titulo": "Borrar SOLPED",
    "rol": "Abastecimiento",
    "descripcion": "Eliminar SOLPED del sistema.",
    "acciones": [
        "Eliminar SOLPED",
        "Guardar cambios"
    ],
    "next": "F1_END_AJUSTE_TOTAL"
},

"F1_END_AJUSTE_TOTAL": {
    "type": "end",
    "titulo": "Proceso finalizado (ajuste total)",
    "show_tables": True
}

# =========================
# ======== FLUJO 2 ========
# =========================

"F2_START_1": {
    "type": "task",
    "titulo": "Existencia de costos indirectos planificados pendientes",
    "rol": "Analista Control y Procesos",
    "descripcion": "Identificar Órdenes de Compra de materiales con costos indirectos planificados pendientes de regularización.",
    "acciones": [
        "Revisar Órdenes de Compra con costos indirectos planificados pendientes",
        "Identificar diferencias entre lo provisionado y lo ejecutado",
        "Confirmar que el caso corresponde al alcance del flujo"
    ],
    "next": "F2_ANALIZAR_COSTOS"
},

"F2_START_2": {
    "type": "task",
    "titulo": "Existencia de provisiones pendientes por regularizar",
    "rol": "Analista Control y Procesos",
    "descripcion": "Identificar provisiones pendientes asociadas a Órdenes de Compra de materiales con costos indirectos planificados.",
    "acciones": [
        "Revisar provisiones pendientes vinculadas a la OC",
        "Validar que la provisión requiere análisis",
        "Confirmar que el caso corresponde al alcance del flujo"
    ],
    "next": "F2_ANALIZAR_COSTOS"
},

"F2_ANALIZAR_COSTOS": {
    "type": "task",
    "titulo": "Analizar costos indirectos pendientes",
    "rol": "Analista Control y Procesos",
    "descripcion": "Analizar los costos indirectos pendientes para determinar si corresponde continuar con la gestión.",
    "acciones": [
        "Revisar costos indirectos pendientes en la Orden de Compra",
        "Validar diferencias entre lo solicitado, provisionado y recepcionado",
        "Determinar si existen costos pendientes por gestionar"
    ],
    "next": "F2_DEC_COSTOS_PENDIENTES"
},

"F2_DEC_COSTOS_PENDIENTES": {
    "type": "decision",
    "titulo": "¿Existen costos pendientes?",
    "rol": "Analista Control y Procesos",
    "descripcion": "Determinar si existen costos indirectos pendientes que requieran regularización.",
    "opciones": {
        "SI": "F2_VALIDAR_FACTURA",
        "NO": "F2_END_SIN_COSTOS"
    }
},

"F2_END_SIN_COSTOS": {
    "type": "end",
    "titulo": "Gestión finalizada",
    "show_tables": True
},

"F2_VALIDAR_FACTURA": {
    "type": "task",
    "titulo": "Validar si se recibirá factura",
    "rol": "Analista Control y Procesos",
    "descripcion": "Validar con los antecedentes disponibles si se recibirá factura asociada a los costos pendientes.",
    "acciones": [
        "Revisar estado documental del servicio o material",
        "Validar antecedentes con las áreas involucradas",
        "Determinar si corresponde esperar factura o regularizar"
    ],
    "next": "F2_DEC_RECIBIRA_FACTURA"
},

"F2_DEC_RECIBIRA_FACTURA": {
    "type": "decision",
    "titulo": "¿Se recibirá factura?",
    "rol": "Analista Control y Procesos",
    "descripcion": "Determinar si se recibirá factura asociada a los costos pendientes.",
    "opciones": {
        "SI": "F2_ESPERAR_FACTURA",
        "NO": "F2_SOLICITAR_AJUSTE_MR11"
    }
},

"F2_ESPERAR_FACTURA": {
    "type": "task",
    "titulo": "Esperar factura",
    "rol": "Analista Control y Procesos",
    "descripcion": "Esperar la recepción de la factura para volver a analizar los costos pendientes.",
    "acciones": [
        "Mantener seguimiento del caso",
        "Esperar recepción de factura",
        "Retomar análisis una vez cumplida la condición"
    ],
    "next": "F2_ANALIZAR_COSTOS"
},

"F2_START_3": {
    "type": "task",
    "titulo": "Diferencia en cantidades entre material solicitado y material recepcionado",
    "rol": "Analista Control y Procesos",
    "descripcion": "Identificar diferencias de cantidades entre material solicitado y material recepcionado que requieran ajuste.",
    "acciones": [
        "Revisar diferencia entre cantidad solicitada y recepcionada",
        "Confirmar que corresponde gestionar ajuste",
        "Iniciar regularización del caso"
    ],
    "next": "F2_SOLICITAR_AJUSTE_MR11"
},

"F2_SOLICITAR_AJUSTE_MR11": {
    "type": "task",
    "titulo": "Solicitar ajuste en MR11",
    "rol": "Analista Control y Procesos",
    "descripcion": "Solicitar el ajuste correspondiente en MR11 para regularizar la diferencia identificada.",
    "acciones": [
        "Preparar antecedentes del ajuste",
        "Solicitar ajuste en MR11",
        "Verificar que la solicitud quede correctamente emitida"
    ],
    "next": "F2_DEC_MONTO_5"
},

"F2_DEC_MONTO_5": {
    "type": "decision",
    "titulo": "¿El monto del ajuste es mayor al 5% del total de la factura?",
    "rol": "Analista Control y Procesos",
    "descripcion": "Determinar si el monto del ajuste supera el umbral definido para requerir aprobación.",
    "opciones": {
        "SI": "F2_SOLICITAR_APROBACION",
        "NO": "F2_VALIDAR_EJECUTAR_REVISION"
    }
},

"F2_SOLICITAR_APROBACION": {
    "type": "task",
    "titulo": "Solicitar aprobación a gerente de contabilidad y gte abastecimiento",
    "rol": "Analista Control y Procesos",
    "descripcion": "Solicitar aprobación formal cuando el monto del ajuste supera el 5% del total de la factura.",
    "acciones": [
        "Preparar antecedentes de la solicitud",
        "Enviar solicitud de aprobación a gerente de contabilidad y gte abastecimiento",
        "Esperar respuesta formal de aprobación"
    ],
    "next": "F2_APROBAR_SOLICITUD"
},

"F2_APROBAR_SOLICITUD": {
    "type": "task",
    "titulo": "Aprobar solicitud",
    "rol": "Gerente de Contabilidad / Gerente de Abastecimiento",
    "descripcion": "Revisar la solicitud de ajuste y resolver su aprobación o rechazo.",
    "acciones": [
        "Revisar antecedentes del ajuste solicitado",
        "Evaluar impacto del ajuste",
        "Emitir decisión formal"
    ],
    "next": "F2_DEC_SOLICITUD_APROBADA"
},

"F2_DEC_SOLICITUD_APROBADA": {
    "type": "decision",
    "titulo": "¿Solicitud aprobada?",
    "rol": "Gerente de Contabilidad / Gerente de Abastecimiento",
    "descripcion": "Determinar si la solicitud de ajuste fue aprobada.",
    "opciones": {
        "SI": "F2_VALIDAR_EJECUTAR_REVISION",
        "NO": "F2_SOLICITAR_AJUSTE_MR11"
    }
},

"F2_VALIDAR_EJECUTAR_REVISION": {
    "type": "task",
    "titulo": "Validar y ejecutar revisión",
    "rol": "Analista Control y Procesos",
    "descripcion": "Validar antecedentes y ejecutar la revisión correspondiente al ajuste.",
    "acciones": [
        "Revisar antecedentes del ajuste",
        "Validar consistencia de la información",
        "Ejecutar revisión correspondiente"
    ],
    "next": "F2_DEC_RECLASIFICAR"
},

"F2_DEC_RECLASIFICAR": {
    "type": "decision",
    "titulo": "¿Se debe reclasificar material consumido?",
    "rol": "Analista Control y Procesos",
    "descripcion": "Determinar si corresponde reclasificar material consumido como parte de la regularización.",
    "opciones": {
        "SI": "F2_RECLASIFICAR_AJUSTE",
        "NO": "F2_INFORMAR_AJUSTE"
    }
},

"F2_RECLASIFICAR_AJUSTE": {
    "type": "task",
    "titulo": "Realizar reclasificación del ajuste contable",
    "rol": "Analista Contable",
    "descripcion": "Ejecutar la reclasificación contable correspondiente al ajuste realizado.",
    "acciones": [
        "Preparar antecedentes para reclasificación",
        "Ejecutar reclasificación contable",
        "Verificar registro de la reclasificación"
    ],
    "next": "F2_INFORMAR_CLASIFICACION"
},

"F2_INFORMAR_CLASIFICACION": {
    "type": "task",
    "titulo": "Informar clasificación realizada",
    "rol": "Analista Contable",
    "descripcion": "Informar que la reclasificación contable fue ejecutada correctamente.",
    "acciones": [
        "Informar resultado de la reclasificación",
        "Confirmar recepción de la información",
        "Dejar trazabilidad del cierre de la reclasificación"
    ],
    "next": "F2_INFORMAR_AJUSTE"
},

"F2_INFORMAR_AJUSTE": {
    "type": "task",
    "titulo": "Informar ajuste realizado",
    "rol": "Analista Control y Procesos",
    "descripcion": "Informar que el ajuste fue realizado y se encuentra listo para validación final.",
    "acciones": [
        "Informar ajuste ejecutado",
        "Confirmar recepción de la información",
        "Dejar trazabilidad del ajuste realizado"
    ],
    "next": "F2_VALIDAR_AJUSTE_OC"
},

"F2_VALIDAR_AJUSTE_OC": {
    "type": "task",
    "titulo": "Validar ajuste en OC",
    "rol": "Analista Control y Procesos",
    "descripcion": "Validar que el ajuste haya quedado correctamente reflejado en la Orden de Compra.",
    "acciones": [
        "Revisar Orden de Compra ajustada",
        "Validar consistencia del ajuste aplicado",
        "Confirmar cierre del caso"
    ],
    "next": "F2_END"
},

"F2_END": {
    "type": "end",
    "titulo": "Proceso finalizado flujo 2",
    "show_tables": True
},

# =========================
# ======== FLUJO 3 ========
# =========================

"F3_START": {
    "type": "task",
    "titulo": "Existencia de HES pendientes de recepción de factura",
    "rol": "Analista Control y Procesos",
    "descripcion": "Identificar HES pendientes de recepción de factura dentro del control mensual de Órdenes de Compra de servicios.",
    "acciones": [
        "Revisar existencia de HES pendientes de recepción de factura",
        "Confirmar que el caso corresponde al alcance del flujo",
        "Iniciar revisión del caso"
    ],
    "next": "F3_REVISAR_STATUS_HES"
},

"F3_REVISAR_STATUS_HES": {
    "type": "task",
    "titulo": "Revisar status de HES",
    "rol": "Analista Control y Procesos",
    "descripcion": "Revisar el estado de las HES pendientes de recepción de factura.",
    "acciones": [
        "Consultar status actual de la HES",
        "Validar antigüedad y condición de la HES",
        "Identificar necesidad de gestión con usuario"
    ],
    "next": "F3_GESTIONAR_USUARIO"
},

"F3_GESTIONAR_USUARIO": {
    "type": "task",
    "titulo": "Gestionar con usuario",
    "rol": "Analista Control y Procesos",
    "descripcion": "Gestionar con el usuario la situación de la HES pendiente de recepción de factura.",
    "acciones": [
        "Contactar al usuario responsable",
        "Solicitar antecedentes del estado de la HES",
        "Confirmar situación de la factura pendiente"
    ],
    "next": "F3_REVISAR_HES_REGISTRADA"
},

"F3_REVISAR_HES_REGISTRADA": {
    "type": "task",
    "titulo": "Revisar HES correctamente registrada",
    "rol": "Analista Control y Procesos",
    "descripcion": "Revisar que la HES se encuentre correctamente registrada antes de continuar con la decisión del flujo.",
    "acciones": [
        "Revisar datos registrados de la HES",
        "Validar consistencia de la HES en sistema",
        "Confirmar que la HES corresponde al caso en análisis"
    ],
    "inputs": [
        {"label": "Ingresa número de HES", "key": "numero_hes_f3", "required": True}
    ],
    "next": "F3_DEC_RECIBIRA_FACTURA"
},

"F3_DEC_RECIBIRA_FACTURA": {
    "type": "decision",
    "titulo": "¿Se recibirá factura de parte del proveedor?",
    "rol": "Analista Control y Procesos",
    "descripcion": "Determinar si el proveedor enviará factura asociada a la HES.",
    "opciones": {
        "SI": "F3_REALIZAR_SEGUIMIENTO",
        "NO": "F3_SOLICITAR_ANULACION_HES"
    }
},

"F3_REALIZAR_SEGUIMIENTO": {
    "type": "task",
    "titulo": "Realizar seguimiento",
    "rol": "Analista Control y Procesos",
    "descripcion": "Realizar seguimiento a la recepción de la factura por parte del proveedor.",
    "acciones": [
        "Hacer seguimiento a la recepción de la factura",
        "Mantener contacto con el usuario o proveedor según corresponda",
        "Confirmar estado del documento pendiente"
    ],
    "next": "F3_RECEPCION_FACTURA"
},

"F3_RECEPCION_FACTURA": {
    "type": "task",
    "titulo": "Recepción de factura",
    "rol": "Analista Control y Procesos",
    "descripcion": "Confirmar la recepción de la factura asociada a la HES.",
    "acciones": [
        "Confirmar recepción de factura",
        "Verificar que la factura corresponde a la HES",
        "Dejar trazabilidad de la recepción"
    ],
    "next": "F3_REVISION_REGISTRO_FACTURA"
},

"F3_REVISION_REGISTRO_FACTURA": {
    "type": "task",
    "titulo": "Revisión y registro de factura",
    "rol": "Analista Control y Procesos",
    "descripcion": "Revisar y registrar la factura recibida para cerrar el caso.",
    "acciones": [
        "Revisar consistencia de la factura recibida",
        "Registrar factura según procedimiento",
        "Confirmar cierre del caso"
    ],
    "next": "F3_END_FACTURA"
},

"F3_END_FACTURA": {
    "type": "end",
    "titulo": "Proceso finalizado (factura recibida)",
    "show_tables": True
},

"F3_SOLICITAR_ANULACION_HES": {
    "type": "task",
    "titulo": "Solicitar anulación de liberación de HES",
    "rol": "Abastecimiento",
    "descripcion": "Solicitar anulación de liberación de la HES cuando no se recibirá factura.",
    "acciones": [
        "Solicitar anulación de liberación de HES",
        "Verificar que la solicitud quede correctamente emitida",
        "Dejar trazabilidad de la solicitud"
    ],
    "next": "F3_REALIZAR_ANULACION_HES"
},

"F3_REALIZAR_ANULACION_HES": {
    "type": "task",
    "titulo": "Realizar anulación de liberación",
    "rol": "Abastecimiento",
    "descripcion": "Ejecutar la anulación de liberación de la HES.",
    "acciones": [
        "Ejecutar anulación de liberación de HES",
        "Confirmar estado de la HES",
        "Verificar resultado de la anulación"
    ],
    "next": "F3_BORRAR_HES"
},

"F3_BORRAR_HES": {
    "type": "task",
    "titulo": "Borrar HES",
    "rol": "Abastecimiento",
    "descripcion": "Eliminar la HES del sistema una vez anulada su liberación.",
    "acciones": [
        "Eliminar HES en sistema",
        "Guardar cambios",
        "Verificar que la HES ya no quede activa"
    ],
    "next": "F3_DEC_AJUSTE_TOTAL"
},

"F3_DEC_AJUSTE_TOTAL": {
    "type": "decision",
    "titulo": "¿El ajuste es total?",
    "rol": "Abastecimiento",
    "descripcion": "Determinar si el ajuste asociado al caso es total o parcial.",
    "opciones": {
        "SI": "F3_BORRAR_PEDIDO",
        "NO": "F3_AJUSTAR_PEDIDO"
    }
},

"F3_AJUSTAR_PEDIDO": {
    "type": "task",
    "titulo": "Ajustar pedido",
    "rol": "Abastecimiento",
    "descripcion": "Ajustar el pedido cuando el caso corresponde a un ajuste parcial.",
    "acciones": [
        "Modificar pedido en sistema",
        "Guardar cambios",
        "Verificar ajuste aplicado"
    ],
    "next": "F3_AJUSTAR_SOLPED"
},

"F3_AJUSTAR_SOLPED": {
    "type": "task",
    "titulo": "Ajustar SOLPED",
    "rol": "Abastecimiento",
    "descripcion": "Ajustar la SOLPED asociada al caso cuando el ajuste no es total.",
    "acciones": [
        "Modificar SOLPED en sistema",
        "Guardar cambios",
        "Verificar ajuste aplicado"
    ],
    "next": "F3_END_AJUSTE_PARCIAL"
},

"F3_END_AJUSTE_PARCIAL": {
    "type": "end",
    "titulo": "Proceso finalizado (ajuste parcial)",
    "show_tables": True
},

"F3_BORRAR_PEDIDO": {
    "type": "task",
    "titulo": "Borrar pedido",
    "rol": "Abastecimiento",
    "descripcion": "Eliminar el pedido cuando el ajuste corresponde a una eliminación total.",
    "acciones": [
        "Eliminar pedido en sistema",
        "Guardar cambios",
        "Verificar eliminación del pedido"
    ],
    "next": "F3_SOLICITAR_ANULACION_SOLPED"
},

"F3_SOLICITAR_ANULACION_SOLPED": {
    "type": "task",
    "titulo": "Solicitar anulación de liberación de SOLPED",
    "rol": "Abastecimiento",
    "descripcion": "Solicitar anulación de liberación de la SOLPED asociada al caso.",
    "acciones": [
        "Solicitar anulación de liberación de SOLPED",
        "Verificar emisión de la solicitud",
        "Dejar trazabilidad de la solicitud"
    ],
    "next": "F3_REALIZAR_ANULACION_SOLPED"
},

"F3_REALIZAR_ANULACION_SOLPED": {
    "type": "task",
    "titulo": "Realizar anulación de liberación",
    "rol": "Abastecimiento",
    "descripcion": "Ejecutar la anulación de liberación de la SOLPED.",
    "acciones": [
        "Ejecutar anulación de liberación de SOLPED",
        "Confirmar estado de la SOLPED",
        "Verificar resultado de la anulación"
    ],
    "next": "F3_BORRAR_SOLPED"
},

"F3_BORRAR_SOLPED": {
    "type": "task",
    "titulo": "Borrar SOLPED",
    "rol": "Abastecimiento",
    "descripcion": "Eliminar la SOLPED del sistema para cerrar el caso.",
    "acciones": [
        "Eliminar SOLPED en sistema",
        "Guardar cambios",
        "Verificar eliminación de la SOLPED"
    ],
    "next": "F3_END_AJUSTE_TOTAL"
},

"F3_END_AJUSTE_TOTAL": {
    "type": "end",
    "titulo": "Proceso finalizado (ajuste total)",
    "show_tables": True
}
